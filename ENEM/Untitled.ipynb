# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('MICRODADOS_ENEM_ESCOLA.csv', sep = ';',
                  encoding = 'ISO-8859-1', low_memory = False)
df = df[df['NU_ANO'] == 2015]
df.head()
# Out:
#        NU_ANO  CO_UF_ESCOLA SG_UF_ESCOLA  CO_MUNICIPIO_ESCOLA  \
# 67619    2015            11           RO              1100205
# 67628    2015            11           RO              1100205
# 67640    2015            11           RO              1100205
# 67642    2015            11           RO              1100205
# 67648    2015            11           RO              1100205
#
#       NO_MUNICIPIO_ESCOLA  CO_ESCOLA_EDUCACENSO  \
# 67619         Porto Velho              11000058
# 67628         Porto Velho              11000171
# 67640         Porto Velho              11000198
# 67642         Porto Velho              11000244
# 67648         Porto Velho              11000252
#
#                                     NO_ESCOLA_EDUCACENSO  \
# 67619                          CENTRO DE ENSINO CLASSE A
# 67628                          CENTRO EDUCACIONAL MOJUCA
# 67640                        CENTRO EDUCACIONAL OBJETIVO
# 67642                                  COLEGIO DOM BOSCO
# ...

# %%
med_red = df.groupby('SG_UF_ESCOLA')['NU_MEDIA_RED'].mean()
med_red.head()
# Out:
# SG_UF_ESCOLA
# AC    454.141670
# AL    489.739782
# AM    465.533140
# AP    453.108046
# BA    467.944056
# Name: NU_MEDIA_RED, dtype: float64

# %%
estados = df['SG_UF_ESCOLA'].unique()
estados.sort()
estados
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
medias = med_red.tolist()
medias
# Out:
# [454.1416704288942,
#  489.73978215038557,
#  465.5331404421321,
#  453.1080456852792,
#  467.9440558601777,
#  470.6352049553641,
#  519.712026037429,
#  460.86621967654946,
#  467.55666288308606,
#  451.4941821946175,
#  487.1002415660127,
#  476.64747675962843,
#  449.0239811643834,
#  470.5246310888253,
#  477.52637328094244,
#  465.62264533749504,
#  446.6608489857243,
#  463.39099164926813,
#  510.4264779104149,
#  468.0903523809524,
#  450.2247579983593,
#  462.8652044609666,
#  494.60751363900073,
#  481.345174914676,
#  480.1724962630789,
#  490.0219149397097,
#  424.3400076335876]

# %%
plt.barh(estados, medias)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_to_plot)

# %%
df.groupby('TP_LOCALIZACAO_ESCOLA')[['NU_MEDIA_MT']].mean()
# Out:
#                        NU_MEDIA_MT
# TP_LOCALIZACAO_ESCOLA
# 1                       514.533799
# 2                       471.877834

# %%
df['TP_LOCALIZACAO_ESCOLA'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
Y = [df[df['TP_LOCALIZACAO_ESCOLA'] == tp]['NU_MEDIA_MT'].tolist()
     for tp in df['TP_LOCALIZACAO_ESCOLA'].unique()]

loc1 = df[df['TP_LOCALIZACAO_ESCOLA'] == 1]['NU_MEDIA_MT'].tolist()
loc2 = df[df['TP_LOCALIZACAO_ESCOLA'] == 2]['NU_MEDIA_MT'].tolist()
y = [loc1, loc2]
y
# Out:
# [[627.66,
#   459.72,
#   507.22,
#   529.87,
#   528.93,
#   492.85,
#   456.92,
#   486.22,
#   417.62,
#   411.69,
#   446.6,
#   428.72,
#   438.82,
#   496.47,
#   427.48,
#   436.36,
#   423.7,
#   464.22,
#   455.35,
#   424.42,
#   418.15,
#   409.78,
#   428.41,
#   414.95,
#   477.28,
#   445.54,
#   458.63,
#   439.32,
#   425.7,
#   425.21,
#   446.17,
#   489.52,
#   445.7,
#   427.32,
#   441.43,
#   435.3,
#   440.66,
#   443.39,
#   399.34,
#   435.35,
#   507.85,
#   425.66,
#   415.54,
#   421.68,
#   427.23,
#   464.98,
#   427.6,
#   436.6,
#   590.97,
#   459.81,
#   435.18,
#   445.21,
#   441.78,
#   421.4,
#   420.88,
#   440.33,
#   449.43,
#   445.97,
#   448.24,
#   445.3,
#   485.22,
#   522.86,
#   450.59,
#   454.46,
#   438.0,
#   426.2,
#   452.38,
#   446.87,
#   440.64,
#   445.38,
#   500.13,
#   431.7,
#   433.4,
#   433.15,
#   427.84,
#   473.7,
#   465.41,
#   435.1,
#   447.81,
#   449.61,
#   440.1,
#   470.43,
#   465.78,
#   424.29,
# ...

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111)
bx = ax.boxplot(Y)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
